# %%
import numpy as np
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### MESC Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset_Segmentation/MESC.csv')
print(df.head(10))
segmentation_df = df[['Utterance','Speaker','StartTime']]
segmentation_df.head(10)
# Out:
#                                            Utterance    Speaker  Emotion  \
# 0                                        I told you.     Client  sadness
# 1                                      Told me what?  Therapist  neutral
# 2  That you'd be sorry you ever encouraged me to ...     Client  sadness
# 3                              I'm not sorry at all.  Therapist  neutral
# 4       You didn't expect it to be like this, I bet.     Client  sadness
# 5                                         Like what?  Therapist  neutral
# 6                                     You know what?     Client  sadness
# 7                                It's disappointing.     Client  sadness
# 8                         I thought I'd feel better,     Client  sadness
# 9                                          relieved.     Client  sadness
#
#                Strategy  Dialogue_ID  Utterance_ID  Season  Episode  \
# 0             undefined            0             0       1        1
# 1         Open question            0             1       1        1
# 2             undefined            0             2       1        1
# 3  Communication Skills            0             3       1        1
# 4             undefined            0             4       1        1
# 5         Open question            0             5       1        1
# 6             undefined            0             6       1        1
# 7             undefined            0             7       1        1
# 8             undefined            0             8       1        1
# 9             undefined            0             9       1        1
#
#       StartTime       EndTime
# 0  00:00:54,097  00:00:55,113
# 1  00:00:55,260  00:00:56,263
# 2  00:00:56,651  00:00:59,719
# 3  00:00:59,951  00:01:01,237
# 4  00:01:03,404  00:01:05,206
# 5  00:01:05,880  00:01:06,826
# 6  00:01:09,711  00:01:10,714
# 7  00:01:11,563  00:01:12,835
# 8  00:01:14,360  00:01:15,993
# 9  00:01:16,106  00:01:17,109
#                                            Utterance    Speaker     StartTime
# 0                                        I told you.     Client  00:00:54,097
# 1                                      Told me what?  Therapist  00:00:55,260
# 2  That you'd be sorry you ever encouraged me to ...     Client  00:00:56,651
# 3                              I'm not sorry at all.  Therapist  00:00:59,951
# 4       You didn't expect it to be like this, I bet.     Client  00:01:03,404
# 5                                         Like what?  Therapist  00:01:05,880
# 6                                     You know what?     Client  00:01:09,711
# 7                                It's disappointing.     Client  00:01:11,563
# 8                         I thought I'd feel better,     Client  00:01:14,360
# 9                                          relieved.     Client  00:01:16,106

# %%
final_segmentation_df = []
current_speaker = segmentation_df.iloc[0]['Speaker']
current_utterance = segmentation_df.iloc[0]['Utterance']

for i in range(1, len(segmentation_df)):
  if segmentation_df.iloc[i]['Speaker'] == current_speaker:
    current_utterance += ' ' + segmentation_df.iloc[i]['Utterance']
  else:
    final_segmentation_df.append({ 'utterance': current_utterance, 'speaker': current_speaker})
    current_speaker = segmentation_df.iloc[i]['Speaker']
    current_utterance = segmentation_df.iloc[i]['Utterance']

final_segmentation_df.append({ 'utterance': current_utterance, 'speaker': current_speaker})
final_segmentation_df = pd.DataFrame(final_segmentation_df)
final_segmentation_df.head(10)
# Out:
#                                            utterance    speaker
# 0                                        I told you.     Client
# 1                                      Told me what?  Therapist
# 2  That you'd be sorry you ever encouraged me to ...     Client
# 3                              I'm not sorry at all.  Therapist
# 4       You didn't expect it to be like this, I bet.     Client
# 5                                         Like what?  Therapist
# 6  You know what? It's disappointing. I thought I...     Client
# 7                                      And it isn't?  Therapist
# 8  No, it's horrible. I don't know if I'm able to...     Client
# 9                                 Are you all right?  Therapist

# %% [markdown]
# #### DIAC-WOZ

# %%
def merging_data(df):
  df = df[['value','speaker']]
  df = df.rename(columns={'value': 'Utterance'})
  df['speaker'] = df['speaker'].replace('Ellie','Therapist')
  df['speaker'] = df['speaker'].replace('Participant','Client')

  merged_df = []
  current_speaker = df.iloc[0]['speaker']
  current_utterance = df.iloc[0]['Utterance']

  for i in range(1, len(df)):
    if df.iloc[i]['speaker'] == current_speaker:
      current_utterance += ' ' + df.iloc[i]['Utterance']
    else:
      merged_df.append({ 'utterance': current_utterance, 'speaker': current_speaker})
      current_speaker = df.iloc[i]['speaker']
      current_utterance = df.iloc[i]['Utterance']

  merged_df.append({ 'utterance': current_utterance, 'speaker': current_speaker})
  merged_df = pd.DataFrame(merged_df)
  return merged_df

# %%
final_merged_df = pd.DataFrame()

for i in range(300,493):
  file_path = f"/content/drive/MyDrive/Dataset_Segmentation/Transcripts/{i}_TRANSCRIPT.csv"
  try:
    df = pd.read_csv(file_path, sep="\t")
    print(f"Successfully loaded {file_path}")
    data = merging_data(df)
    final_merged_df = pd.concat([final_merged_df, data], ignore_index=True)
  except FileNotFoundError:
    print(f"File {file_path} not found, skipping...")
  except Exception as e:
    print(f"An error occurred with file {file_path}: {e}")

print(final_merged_df.shape)
final_merged_df.head(10)
# Out:
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/300_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/301_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/302_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/303_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/304_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/305_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/306_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/307_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/308_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/309_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/310_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/311_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/312_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/313_TRANSCRIPT.csv
# An error occurred with file /content/drive/MyDrive/Dataset_Segmentation/Transcripts/313_TRANSCRIPT.csv: can only concatenate str (not "float") to str
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/314_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/315_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/316_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/317_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/318_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/319_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/320_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/321_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/322_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/323_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/324_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/325_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/326_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/327_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/328_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/329_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/330_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/331_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/332_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/333_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/334_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/335_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/336_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/337_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/338_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/339_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/340_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/341_TRANSCRIPT.csv
# File /content/drive/MyDrive/Dataset_Segmentation/Transcripts/342_TRANSCRIPT.csv not found, skipping...
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/343_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/344_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/345_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/346_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/347_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/348_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/349_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/350_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/351_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/352_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/353_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/354_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/355_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/356_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/357_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/358_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/359_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/360_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/361_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/362_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/363_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/364_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/365_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/366_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/367_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/368_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/369_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/370_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/371_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/372_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/373_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/374_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/375_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/376_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/377_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/378_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/379_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/380_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/381_TRANSCRIPT.csv
# An error occurred with file /content/drive/MyDrive/Dataset_Segmentation/Transcripts/381_TRANSCRIPT.csv: can only concatenate str (not "float") to str
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/382_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/383_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/384_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/385_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/386_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/387_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/388_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/389_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/390_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/391_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/392_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/393_TRANSCRIPT.csv
# File /content/drive/MyDrive/Dataset_Segmentation/Transcripts/394_TRANSCRIPT.csv not found, skipping...
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/395_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/396_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/397_TRANSCRIPT.csv
# File /content/drive/MyDrive/Dataset_Segmentation/Transcripts/398_TRANSCRIPT.csv not found, skipping...
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/399_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/400_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/401_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/402_TRANSCRIPT.csv
# An error occurred with file /content/drive/MyDrive/Dataset_Segmentation/Transcripts/402_TRANSCRIPT.csv: can only concatenate str (not "float") to str
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/403_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/404_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/405_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/406_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/407_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/408_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/409_TRANSCRIPT.csv
# An error occurred with file /content/drive/MyDrive/Dataset_Segmentation/Transcripts/409_TRANSCRIPT.csv: can only concatenate str (not "float") to str
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/410_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/411_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/412_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/413_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/414_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/415_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/416_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/417_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/418_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/419_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/420_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/421_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/422_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/423_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/424_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/425_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/426_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/427_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/428_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/429_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/430_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/431_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/432_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/433_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/434_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/435_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/436_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/437_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/438_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/439_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/440_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/441_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/442_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/443_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/444_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/445_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/446_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/447_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/448_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/449_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/450_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/451_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/452_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/453_TRANSCRIPT.csv
# An error occurred with file /content/drive/MyDrive/Dataset_Segmentation/Transcripts/453_TRANSCRIPT.csv: can only concatenate str (not "float") to str
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/454_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/455_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/456_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/457_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/458_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/459_TRANSCRIPT.csv
# File /content/drive/MyDrive/Dataset_Segmentation/Transcripts/460_TRANSCRIPT.csv not found, skipping...
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/461_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/462_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/463_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/464_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/465_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/466_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/467_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/468_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/469_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/470_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/471_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/472_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/473_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/474_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/475_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/476_TRANSCRIPT.csv
# An error occurred with file /content/drive/MyDrive/Dataset_Segmentation/Transcripts/476_TRANSCRIPT.csv: can only concatenate str (not "float") to str
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/477_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/478_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/479_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/480_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/481_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/482_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/483_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/484_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/485_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/486_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/487_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/488_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/489_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/490_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/491_TRANSCRIPT.csv
# Successfully loaded /content/drive/MyDrive/Dataset_Segmentation/Transcripts/492_TRANSCRIPT.csv
# (20822, 2)
#                                            utterance    speaker
# 0  hi i'm ellie thanks for coming in today i was ...  Therapist
# 1                                               good     Client
# 2          that's good where are you from originally  Therapist
# 3                                    atlanta georgia     Client
# 4                       really why'd you move to l_a  Therapist
# 5                     um my parents are from here um     Client
# 6                                how do you like l_a  Therapist
# 7                                          i love it     Client
# 8     what are some things you really like about l_a  Therapist
# 9  i like the weather i like the opportunities um...     Client

# %% [markdown]
# #### Merging the Data

# %%
final_segmentation_df = pd.concat([final_segmentation_df, final_merged_df], ignore_index=True)
print(final_segmentation_df.shape)
final_segmentation_df.head(10)
# Out:
# (30192, 2)
#                                            utterance    speaker
# 0                                        I told you.     Client
# 1                                      Told me what?  Therapist
# 2  That you'd be sorry you ever encouraged me to ...     Client
# 3                              I'm not sorry at all.  Therapist
# 4       You didn't expect it to be like this, I bet.     Client
# 5                                         Like what?  Therapist
# 6  You know what? It's disappointing. I thought I...     Client
# 7                                      And it isn't?  Therapist
# 8  No, it's horrible. I don't know if I'm able to...     Client
# 9                                 Are you all right?  Therapist

# %%
final_segmentation_df.to_parquet("/content/drive/My Drive/Therapy_Session.parquet", engine="pyarrow", index=False)
